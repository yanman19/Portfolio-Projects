# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import pandas as pd
from datetime import datetime

# Convert DataFrames to string
power_str = power_df.to_string(index=False)
gas_str = gas_df.to_string(index=False)
option_str = option_df.to_string(index=False)

# Construct the email body
email_body = f"Power:\n{power_str}\n\nGas:\n{gas_str}\n\nOption:\n{option_str}"

# Email details
sender_email = "your_email@example.com"  # Replace with your email
receiver_email = "receiver_email@example.com"  # Replace with the receiver's email
password = "your_password"  # Replace with your email password
subject = f"New trade tie out: {datetime.now().strftime('%Y-%m-%d')}"

# Set up the MIME
message = MIMEMultipart()
message['From'] = sender_email
message['To'] = receiver_email
message['Subject'] = subject

# Attach the body with the MIME instance
message.attach(MIMEText(email_body, "plain"))

# Create SMTP session for sending the mail
try:
    with smtplib.SMTP('smtp.example.com', 587) as server:  # Replace with your SMTP server
        server.starttls()  # Enable security
        server.login(sender_email, password)  # Login with your email and password
        text = message.as_string()
        server.sendmail(sender_email, receiver_email, text)
    print("Email sent successfully")
except Exception as e:
    print(f"Error: {e}")

# Note: Replace 'smtp.example.com' with the SMTP server of your email provider
# and make sure to enable 'less secure apps' if using Gmail.
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import pandas as pd
from datetime import datetime

# Convert DataFrames to string
power_str = power_df.to_string(index=False)
gas_str = gas_df.to_string(index=False)
option_str = option_df.to_string(index=False)

# Construct the email body
email_body = f"Power:\n{power_str}\n\nGas:\n{gas_str}\n\nOption:\n{option_str}"

# Email details
sender_email = "your_email@example.com"  # Replace with your email
receiver_email = "receiver_email@example.com"  # Replace with the receiver's email
password = "your_password"  # Replace with your email password
subject = f"New trade tie out: {datetime.now().strftime('%Y-%m-%d')}"

# Set up the MIME
message = MIMEMultipart()
message['From'] = sender_email
message['To'] = receiver_email
message['Subject'] = subject

# Attach the body with the MIME instance
message.attach(MIMEText(email_body, "plain"))

# Create SMTP session for sending the mail
try:
    with smtplib.SMTP('smtp.example.com', 587) as server:  # Replace with your SMTP server
        server.starttls()  # Enable security
        server.login(sender_email, password)  # Login with your email and password
        text = message.as_string()
        server.sendmail(sender_email, receiver_email, text)
    print("Email sent successfully")
except Exception as e:
    print(f"Error: {e}")

# Note: Replace 'smtp.example.com' with the SMTP server of your email provider
# and make sure to enable 'less secure apps' if using Gmail.
