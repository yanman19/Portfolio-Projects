# %% [markdown]
# # Predicting Tomorrow's SP500 Close with XGBoost
#
# In this experiment, I will be attempting to build a model that accurately predicts the closing price of the SP500 for tomorrow. This means that you can run the model after the market closes today and have an understanding as to what to expect for the following day.
#
# I will be using the XGBoost Machine Learning Algorithm to train market data that spans back to 1992 for the open, high, low, close, adj close of the following assets:
#
# SP500
# VIX Index
# 5 yr Treasury Note
# 10 yr Treasury Bond
# 30 yr Treasury Bond
# I will be diagnosing the performance of the model with Cross Validation and predominantly considering the Root Mean Squared Error as my metric of measurement (rmse).
#
# Procedure:
#
# 1. Retreive Data
# 2. Clean and Format Data for Machine Learning
# 3. Fit Model
# 4. Measure Error Metrics with Cross Validation rmse

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('clean_historical_data.csv')

# %%
df['ds'] = pd.to_datetime(df['Date'], format='%Y-%m-%d %H:%M:%S%z').apply(lambda x: x.strftime('%Y-%m-%d'))

# %%
df['ds'] = pd.to_datetime(df['ds'], format='%Y-%m-%d')

# %%
df.Volume_GSPC = df.Volume_GSPC.astype(float)

# %% [markdown]
# # Target Defining:
#
# We want to predict Tomorrow's closing price of the SPX, so we need to have each observation have tomorrow's price to learn from

# %%
df['y'] = df['Adj Close_GSPC'].shift(-1)

# %%
df = df.drop(df.index[-1])

# %%
df.apply(pd.isnull).sum()
# Out:
# Date              0
# Adj Close_FVX     0
# Adj Close_GSPC    0
# Adj Close_TNX     0
# Adj Close_TYX     0
# Adj Close_VIX     0
# Close_FVX         0
# Close_GSPC        0
# Close_TNX         0
# Close_TYX         0
# Close_VIX         0
# High_FVX          0
# High_GSPC         0
# High_TNX          0
# High_TYX          0
# High_VIX          0
# Low_FVX           0
# Low_GSPC          0
# Low_TNX           0
# Low_TYX           0
# Low_VIX           0
# Open_FVX          0
# Open_GSPC         0
# Open_TNX          0
# Open_TYX          0
# Open_VIX          0
# Volume_GSPC       0
# ds                0
# y                 0
# dtype: int64

# %% [markdown]
# # Time Series Cross Validation:
#
# Robust way of measuring success of the model by utilitizing multiple train/tests all together.
#
# ### Disclaimer: For standardization, I will use 62 splits as the original Prophet Cross Validation used:
#
# - training periods of 730 days
# - testing periods of 365 days
# - gaps of 180 days
# - this totalled to 10 splits
#
# Here, we are

# %%
from sklearn.model_selection import TimeSeriesSplit

# %%
tss = TimeSeriesSplit(n_splits=38, test_size=37, gap=180)
df = df.sort_index()

# %%
df.index = df.ds

# %%
df.columns
# Out:
# Index(['Date', 'Adj Close_FVX', 'Adj Close_GSPC', 'Adj Close_TNX',
#        'Adj Close_TYX', 'Adj Close_VIX', 'Close_FVX', 'Close_GSPC',
#        'Close_TNX', 'Close_TYX', 'Close_VIX', 'High_FVX', 'High_GSPC',
#        'High_TNX', 'High_TYX', 'High_VIX', 'Low_FVX', 'Low_GSPC', 'Low_TNX',
#        'Low_TYX', 'Low_VIX', 'Open_FVX', 'Open_GSPC', 'Open_TNX', 'Open_TYX',
#        'Open_VIX', 'Volume_GSPC', 'ds', 'y'],
#       dtype='object')

# %%
fold = 0
preds = []
scores = []
for train_idx, val_idx in tss.split(df):
    train = df.iloc[train_idx]
    test = df.iloc[val_idx]


    FEATURES = ['Adj Close_FVX', 'Adj Close_GSPC', 'Adj Close_TNX',
       'Adj Close_TYX', 'Adj Close_VIX', 'Close_FVX', 'Close_GSPC',
       'Close_TNX', 'Close_TYX', 'Close_VIX', 'High_FVX', 'High_GSPC',
       'High_TNX', 'High_TYX', 'High_VIX', 'Low_FVX', 'Low_GSPC', 'Low_TNX',
       'Low_TYX', 'Low_VIX', 'Open_FVX', 'Open_GSPC', 'Open_TNX', 'Open_TYX',
       'Open_VIX', 'Volume_GSPC']
    TARGET = 'y'

    X_train = train[FEATURES]
    y_train = train[TARGET]

    X_test = test[FEATURES]
    y_test = test[TARGET]

    reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                           n_estimators=1000,
                           early_stopping_rounds=50,
                           objective='reg:linear',
                           max_depth=3,
                           learning_rate=0.01)
    reg.fit(X_train, y_train,
            eval_set=[(X_train, y_train), (X_test, y_test)],
            verbose=100)

    y_pred = reg.predict(X_test)
    preds.append(y_pred)
    score = np.sqrt(mean_squared_error(y_test, y_pred))
    scores.append(score)
# Out:
# [09:01:58] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1200.55913	validation_1-rmse:2528.39148
# [100]	validation_0-rmse:441.91619	validation_1-rmse:1215.29627
# [200]	validation_0-rmse:163.18610	validation_1-rmse:700.45377
# [300]	validation_0-rmse:61.29240	validation_1-rmse:483.29091
# [400]	validation_0-rmse:25.26848	validation_1-rmse:376.14078
# [500]	validation_0-rmse:14.47845	validation_1-rmse:328.99382
# [600]	validation_0-rmse:12.14810	validation_1-rmse:309.63080
# [700]	validation_0-rmse:11.64587	validation_1-rmse:304.88310
# [800]	validation_0-rmse:11.46284	validation_1-rmse:303.00949
# [900]	validation_0-rmse:11.35578	validation_1-rmse:301.95830
# [999]	validation_0-rmse:11.26635	validation_1-rmse:301.30342
# [09:02:13] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1208.94996	validation_1-rmse:2617.87149
# [100]	validation_0-rmse:445.09556	validation_1-rmse:1278.85783
# [200]	validation_0-rmse:164.43302	validation_1-rmse:735.81981
# [300]	validation_0-rmse:61.76279	validation_1-rmse:508.30918
# [400]	validation_0-rmse:25.44313	validation_1-rmse:398.67201
# [500]	validation_0-rmse:14.52855	validation_1-rmse:342.43540
# [600]	validation_0-rmse:12.15937	validation_1-rmse:312.23239
# [700]	validation_0-rmse:11.65354	validation_1-rmse:304.94248
# [800]	validation_0-rmse:11.47450	validation_1-rmse:301.98753
# [900]	validation_0-rmse:11.36170	validation_1-rmse:299.23484
# [999]	validation_0-rmse:11.27319	validation_1-rmse:297.78151
# [09:02:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1217.87346	validation_1-rmse:2732.24533
# [100]	validation_0-rmse:448.46565	validation_1-rmse:1352.13443
# [200]	validation_0-rmse:165.69878	validation_1-rmse:794.46993
# [300]	validation_0-rmse:62.19793	validation_1-rmse:558.93623
# [400]	validation_0-rmse:25.53186	validation_1-rmse:461.36390
# [500]	validation_0-rmse:14.50876	validation_1-rmse:420.98424
# [600]	validation_0-rmse:12.12438	validation_1-rmse:402.73851
# [700]	validation_0-rmse:11.62275	validation_1-rmse:397.23953
# [800]	validation_0-rmse:11.44016	validation_1-rmse:394.10212
# [900]	validation_0-rmse:11.33246	validation_1-rmse:391.85860
# [999]	validation_0-rmse:11.24528	validation_1-rmse:390.16306
# [09:02:46] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1226.99697	validation_1-rmse:2661.62489
# [100]	validation_0-rmse:451.86107	validation_1-rmse:1247.67361
# [200]	validation_0-rmse:166.93481	validation_1-rmse:679.33743
# [300]	validation_0-rmse:62.64216	validation_1-rmse:451.53624
# [400]	validation_0-rmse:25.69733	validation_1-rmse:356.57381
# [500]	validation_0-rmse:14.56018	validation_1-rmse:311.50041
# [600]	validation_0-rmse:12.13470	validation_1-rmse:290.62924
# [700]	validation_0-rmse:11.61949	validation_1-rmse:285.24860
# [800]	validation_0-rmse:11.43897	validation_1-rmse:283.51964
# [900]	validation_0-rmse:11.32671	validation_1-rmse:282.41966
# [999]	validation_0-rmse:11.23615	validation_1-rmse:281.97280
# [09:03:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1236.47123	validation_1-rmse:2687.91613
# [100]	validation_0-rmse:455.37104	validation_1-rmse:1241.95087
# [200]	validation_0-rmse:168.24008	validation_1-rmse:668.33219
# [300]	validation_0-rmse:63.12678	validation_1-rmse:432.28337
# [400]	validation_0-rmse:25.85279	validation_1-rmse:330.99531
# [500]	validation_0-rmse:14.57905	validation_1-rmse:283.05515
# [600]	validation_0-rmse:12.12458	validation_1-rmse:261.82273
# [700]	validation_0-rmse:11.60602	validation_1-rmse:257.12955
# [800]	validation_0-rmse:11.42613	validation_1-rmse:254.03590
# [900]	validation_0-rmse:11.31965	validation_1-rmse:253.13795
# [999]	validation_0-rmse:11.23034	validation_1-rmse:252.32806
# [09:03:18] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1245.99842	validation_1-rmse:2758.97580
# [100]	validation_0-rmse:458.86656	validation_1-rmse:1288.63893
# [200]	validation_0-rmse:169.53225	validation_1-rmse:709.56488
# [300]	validation_0-rmse:63.58559	validation_1-rmse:475.27951
# [400]	validation_0-rmse:25.99798	validation_1-rmse:375.88066
# [500]	validation_0-rmse:14.61384	validation_1-rmse:329.75698
# [600]	validation_0-rmse:12.12748	validation_1-rmse:306.41060
# [700]	validation_0-rmse:11.60296	validation_1-rmse:301.60008
# [800]	validation_0-rmse:11.42511	validation_1-rmse:298.47009
# [900]	validation_0-rmse:11.31307	validation_1-rmse:297.31607
# [999]	validation_0-rmse:11.23022	validation_1-rmse:296.33012
# [09:03:34] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1256.29085	validation_1-rmse:2857.16453
# [100]	validation_0-rmse:462.70921	validation_1-rmse:1357.80816
# [200]	validation_0-rmse:171.02714	validation_1-rmse:759.30703
# [300]	validation_0-rmse:64.18203	validation_1-rmse:502.28422
# [400]	validation_0-rmse:26.20372	validation_1-rmse:390.96993
# [500]	validation_0-rmse:14.64825	validation_1-rmse:343.01502
# [600]	validation_0-rmse:12.11667	validation_1-rmse:319.08152
# [700]	validation_0-rmse:11.59068	validation_1-rmse:313.82024
# [800]	validation_0-rmse:11.41165	validation_1-rmse:311.51109
# [900]	validation_0-rmse:11.30336	validation_1-rmse:310.16972
# [999]	validation_0-rmse:11.21352	validation_1-rmse:309.40458
# [09:03:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1267.47353	validation_1-rmse:2750.53164
# [100]	validation_0-rmse:466.94756	validation_1-rmse:1210.42747
# [200]	validation_0-rmse:172.69537	validation_1-rmse:578.82859
# [300]	validation_0-rmse:64.85853	validation_1-rmse:305.84394
# [400]	validation_0-rmse:26.48127	validation_1-rmse:187.23343
# [500]	validation_0-rmse:14.73657	validation_1-rmse:130.61961
# [600]	validation_0-rmse:12.13450	validation_1-rmse:104.74392
# [700]	validation_0-rmse:11.60765	validation_1-rmse:99.48396
# [800]	validation_0-rmse:11.40868	validation_1-rmse:96.67837
# [900]	validation_0-rmse:11.29812	validation_1-rmse:95.20611
# [999]	validation_0-rmse:11.20930	validation_1-rmse:94.18137
# [09:04:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1279.38664	validation_1-rmse:2568.18142
# [100]	validation_0-rmse:471.43108	validation_1-rmse:980.05135
# [200]	validation_0-rmse:174.42091	validation_1-rmse:371.93219
# [300]	validation_0-rmse:65.54989	validation_1-rmse:140.75304
# [400]	validation_0-rmse:26.78682	validation_1-rmse:63.45196
# [500]	validation_0-rmse:14.91555	validation_1-rmse:46.73459
# [600]	validation_0-rmse:12.28510	validation_1-rmse:45.74019
# [632]	validation_0-rmse:12.02670	validation_1-rmse:45.82439
# [09:04:17] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1290.29802	validation_1-rmse:2703.40319
# [100]	validation_0-rmse:475.41838	validation_1-rmse:1084.46602
# [200]	validation_0-rmse:175.87027	validation_1-rmse:438.98767
# [300]	validation_0-rmse:66.07727	validation_1-rmse:178.73696
# [400]	validation_0-rmse:27.01211	validation_1-rmse:73.56308
# [500]	validation_0-rmse:15.06099	validation_1-rmse:35.90490
# [600]	validation_0-rmse:12.41038	validation_1-rmse:22.48274
# [700]	validation_0-rmse:11.86757	validation_1-rmse:20.41997
# [800]	validation_0-rmse:11.65793	validation_1-rmse:19.71866
# [900]	validation_0-rmse:11.53507	validation_1-rmse:19.53630
# [999]	validation_0-rmse:11.44723	validation_1-rmse:19.48494
# [09:04:33] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1301.54384	validation_1-rmse:2845.48729
# [100]	validation_0-rmse:479.59411	validation_1-rmse:1207.22749
# [200]	validation_0-rmse:177.36666	validation_1-rmse:557.13528
# [300]	validation_0-rmse:66.58863	validation_1-rmse:285.16630
# [400]	validation_0-rmse:27.17725	validation_1-rmse:163.42245
# [500]	validation_0-rmse:15.10738	validation_1-rmse:104.71798
# [600]	validation_0-rmse:12.42585	validation_1-rmse:79.32084
# [700]	validation_0-rmse:11.87946	validation_1-rmse:70.94447
# [800]	validation_0-rmse:11.68340	validation_1-rmse:68.86142
# [900]	validation_0-rmse:11.56166	validation_1-rmse:67.56748
# [999]	validation_0-rmse:11.47287	validation_1-rmse:65.60471
# [09:04:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1313.26395	validation_1-rmse:2837.60647
# [100]	validation_0-rmse:483.99289	validation_1-rmse:1176.00213
# [200]	validation_0-rmse:178.96170	validation_1-rmse:516.54280
# [300]	validation_0-rmse:67.15101	validation_1-rmse:246.33812
# [400]	validation_0-rmse:27.33990	validation_1-rmse:134.20212
# [500]	validation_0-rmse:15.13965	validation_1-rmse:85.90353
# [600]	validation_0-rmse:12.43969	validation_1-rmse:68.53983
# [700]	validation_0-rmse:11.88181	validation_1-rmse:62.36210
# [800]	validation_0-rmse:11.68849	validation_1-rmse:60.26201
# [864]	validation_0-rmse:11.61923	validation_1-rmse:60.24084
# [09:05:05] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1325.83170	validation_1-rmse:2930.41885
# [100]	validation_0-rmse:488.73893	validation_1-rmse:1233.48945
# [200]	validation_0-rmse:180.76407	validation_1-rmse:556.69475
# [300]	validation_0-rmse:67.83198	validation_1-rmse:273.34744
# [400]	validation_0-rmse:27.57087	validation_1-rmse:152.80530
# [500]	validation_0-rmse:15.18773	validation_1-rmse:104.76377
# [600]	validation_0-rmse:12.43277	validation_1-rmse:91.14998
# [700]	validation_0-rmse:11.87083	validation_1-rmse:86.33527
# [800]	validation_0-rmse:11.68638	validation_1-rmse:83.88680
# [900]	validation_0-rmse:11.57652	validation_1-rmse:82.68717
# [999]	validation_0-rmse:11.49375	validation_1-rmse:81.96838
# [09:05:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1336.55497	validation_1-rmse:2920.94001
# [100]	validation_0-rmse:492.66963	validation_1-rmse:1217.54206
# [200]	validation_0-rmse:182.22036	validation_1-rmse:546.87032
# [300]	validation_0-rmse:68.39530	validation_1-rmse:263.76475
# [400]	validation_0-rmse:27.84710	validation_1-rmse:142.80213
# [500]	validation_0-rmse:15.41049	validation_1-rmse:95.46836
# [600]	validation_0-rmse:12.64196	validation_1-rmse:79.26479
# [700]	validation_0-rmse:12.07478	validation_1-rmse:73.97114
# [800]	validation_0-rmse:11.88089	validation_1-rmse:71.62649
# [900]	validation_0-rmse:11.77911	validation_1-rmse:70.90608
# [999]	validation_0-rmse:11.68926	validation_1-rmse:70.65020
# [09:05:37] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1345.62245	validation_1-rmse:3033.83129
# [100]	validation_0-rmse:496.01754	validation_1-rmse:1331.52046
# [200]	validation_0-rmse:183.46852	validation_1-rmse:662.47540
# [300]	validation_0-rmse:68.88539	validation_1-rmse:377.32218
# [400]	validation_0-rmse:28.09693	validation_1-rmse:252.32940
# [500]	validation_0-rmse:15.62109	validation_1-rmse:200.97882
# [600]	validation_0-rmse:12.84136	validation_1-rmse:180.89817
# [700]	validation_0-rmse:12.25953	validation_1-rmse:174.90496
# [800]	validation_0-rmse:12.06622	validation_1-rmse:173.10616
# [900]	validation_0-rmse:11.95860	validation_1-rmse:171.61218
# [999]	validation_0-rmse:11.86390	validation_1-rmse:170.45083
# [09:05:51] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1356.11212	validation_1-rmse:3199.38120
# [100]	validation_0-rmse:499.86304	validation_1-rmse:1490.23333
# [200]	validation_0-rmse:184.86569	validation_1-rmse:826.43755
# [300]	validation_0-rmse:69.39466	validation_1-rmse:542.03782
# [400]	validation_0-rmse:28.27856	validation_1-rmse:416.65603
# [500]	validation_0-rmse:15.68871	validation_1-rmse:364.09164
# [600]	validation_0-rmse:12.88645	validation_1-rmse:343.65492
# [700]	validation_0-rmse:12.29808	validation_1-rmse:336.81792
# [800]	validation_0-rmse:12.10819	validation_1-rmse:334.93381
# [900]	validation_0-rmse:11.99835	validation_1-rmse:333.68025
# [999]	validation_0-rmse:11.90623	validation_1-rmse:332.22850
# [09:06:06] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1367.75973	validation_1-rmse:3065.05128
# [100]	validation_0-rmse:504.19309	validation_1-rmse:1371.91578
# [200]	validation_0-rmse:186.46359	validation_1-rmse:731.84155
# [300]	validation_0-rmse:69.95623	validation_1-rmse:478.44892
# [400]	validation_0-rmse:28.45936	validation_1-rmse:379.50323
# [500]	validation_0-rmse:15.73574	validation_1-rmse:341.69636
# [600]	validation_0-rmse:12.89735	validation_1-rmse:325.32999
# [700]	validation_0-rmse:12.30995	validation_1-rmse:318.79303
# [800]	validation_0-rmse:12.11617	validation_1-rmse:317.55456
# [900]	validation_0-rmse:12.00582	validation_1-rmse:316.68928
# [986]	validation_0-rmse:11.92582	validation_1-rmse:316.41762
# [09:06:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1379.05120	validation_1-rmse:2704.25117
# [100]	validation_0-rmse:508.36729	validation_1-rmse:1024.38641
# [200]	validation_0-rmse:187.98941	validation_1-rmse:398.99933
# [300]	validation_0-rmse:70.51155	validation_1-rmse:171.80135
# [400]	validation_0-rmse:28.66907	validation_1-rmse:100.70927
# [500]	validation_0-rmse:15.83307	validation_1-rmse:82.66556
# [600]	validation_0-rmse:12.96917	validation_1-rmse:78.72467
# [700]	validation_0-rmse:12.38063	validation_1-rmse:77.56069
# [800]	validation_0-rmse:12.17773	validation_1-rmse:77.65765
# [812]	validation_0-rmse:12.16101	validation_1-rmse:77.66097
# [09:06:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1390.98030	validation_1-rmse:3030.49356
# [100]	validation_0-rmse:512.82040	validation_1-rmse:1273.48560
# [200]	validation_0-rmse:189.66410	validation_1-rmse:593.60194
# [300]	validation_0-rmse:71.19434	validation_1-rmse:315.31309
# [400]	validation_0-rmse:28.97323	validation_1-rmse:191.56741
# [500]	validation_0-rmse:15.99099	validation_1-rmse:140.56967
# [600]	validation_0-rmse:13.09026	validation_1-rmse:124.74072
# [700]	validation_0-rmse:12.49520	validation_1-rmse:117.15537
# [763]	validation_0-rmse:12.34340	validation_1-rmse:117.64353
# [09:06:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1402.74331	validation_1-rmse:3266.63559
# [100]	validation_0-rmse:517.17031	validation_1-rmse:1491.02860
# [200]	validation_0-rmse:191.26073	validation_1-rmse:805.38588
# [300]	validation_0-rmse:71.75972	validation_1-rmse:516.74662
# [400]	validation_0-rmse:29.15758	validation_1-rmse:396.41534
# [500]	validation_0-rmse:16.05968	validation_1-rmse:345.21082
# [600]	validation_0-rmse:13.13412	validation_1-rmse:327.02532
# [700]	validation_0-rmse:12.53878	validation_1-rmse:315.72324
# [800]	validation_0-rmse:12.32640	validation_1-rmse:307.53850
# [900]	validation_0-rmse:12.20801	validation_1-rmse:303.39424
# [999]	validation_0-rmse:12.11356	validation_1-rmse:301.59455
# [09:06:56] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1415.56951	validation_1-rmse:3375.86726
# [100]	validation_0-rmse:522.00551	validation_1-rmse:1570.20180
# [200]	validation_0-rmse:193.16643	validation_1-rmse:861.00940
# [300]	validation_0-rmse:72.54058	validation_1-rmse:543.75478
# [400]	validation_0-rmse:29.46343	validation_1-rmse:403.29274
# [500]	validation_0-rmse:16.15265	validation_1-rmse:339.94362
# [600]	validation_0-rmse:13.16676	validation_1-rmse:317.91875
# [700]	validation_0-rmse:12.56591	validation_1-rmse:303.78215
# [800]	validation_0-rmse:12.35244	validation_1-rmse:296.29908
# [900]	validation_0-rmse:12.23839	validation_1-rmse:291.39967
# [999]	validation_0-rmse:12.13843	validation_1-rmse:287.15404
# [09:07:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1429.90859	validation_1-rmse:3508.79671
# [100]	validation_0-rmse:527.51095	validation_1-rmse:1639.67320
# [200]	validation_0-rmse:195.32005	validation_1-rmse:869.08682
# [300]	validation_0-rmse:73.37504	validation_1-rmse:533.64051
# [400]	validation_0-rmse:29.77883	validation_1-rmse:389.37040
# [500]	validation_0-rmse:16.25732	validation_1-rmse:320.03986
# [600]	validation_0-rmse:13.21096	validation_1-rmse:286.01740
# [700]	validation_0-rmse:12.60066	validation_1-rmse:268.21501
# [800]	validation_0-rmse:12.38658	validation_1-rmse:260.30220
# [842]	validation_0-rmse:12.33038	validation_1-rmse:260.59829
# [09:07:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1441.28759	validation_1-rmse:3733.73075
# [100]	validation_0-rmse:531.78467	validation_1-rmse:1826.70763
# [200]	validation_0-rmse:196.97898	validation_1-rmse:1033.93152
# [300]	validation_0-rmse:74.21921	validation_1-rmse:696.99641
# [400]	validation_0-rmse:30.64785	validation_1-rmse:543.84875
# [500]	validation_0-rmse:17.35117	validation_1-rmse:499.51004
# [600]	validation_0-rmse:14.20578	validation_1-rmse:488.19607
# [700]	validation_0-rmse:13.41701	validation_1-rmse:483.32586
# [706]	validation_0-rmse:13.39084	validation_1-rmse:483.29686
# [09:07:30] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1450.61525	validation_1-rmse:3874.31848
# [100]	validation_0-rmse:535.19997	validation_1-rmse:1969.75086
# [200]	validation_0-rmse:198.25872	validation_1-rmse:1175.01184
# [300]	validation_0-rmse:74.76977	validation_1-rmse:837.26376
# [400]	validation_0-rmse:31.03397	validation_1-rmse:685.30106
# [500]	validation_0-rmse:17.80529	validation_1-rmse:631.98340
# [600]	validation_0-rmse:14.78097	validation_1-rmse:619.91689
# [700]	validation_0-rmse:13.91244	validation_1-rmse:617.30039
# [712]	validation_0-rmse:13.85434	validation_1-rmse:618.22535
# [09:07:39] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1462.69757	validation_1-rmse:4113.56231
# [100]	validation_0-rmse:539.59398	validation_1-rmse:2198.25116
# [200]	validation_0-rmse:199.87370	validation_1-rmse:1413.50098
# [300]	validation_0-rmse:75.39139	validation_1-rmse:1075.97543
# [400]	validation_0-rmse:31.34650	validation_1-rmse:924.44025
# [500]	validation_0-rmse:18.06781	validation_1-rmse:858.62015
# [600]	validation_0-rmse:15.01365	validation_1-rmse:840.14002
# [700]	validation_0-rmse:14.17563	validation_1-rmse:832.19353
# [728]	validation_0-rmse:14.06023	validation_1-rmse:832.51148
# [09:07:49] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1477.12196	validation_1-rmse:4233.73964
# [100]	validation_0-rmse:544.97012	validation_1-rmse:2261.78288
# [200]	validation_0-rmse:201.90760	validation_1-rmse:1461.05580
# [300]	validation_0-rmse:76.19788	validation_1-rmse:1113.04471
# [400]	validation_0-rmse:31.69775	validation_1-rmse:944.11016
# [500]	validation_0-rmse:18.22809	validation_1-rmse:863.47015
# [600]	validation_0-rmse:15.08150	validation_1-rmse:835.00649
# [700]	validation_0-rmse:14.20333	validation_1-rmse:822.33486
# [800]	validation_0-rmse:13.82196	validation_1-rmse:816.83257
# [900]	validation_0-rmse:13.60975	validation_1-rmse:812.92362
# [999]	validation_0-rmse:13.44901	validation_1-rmse:811.00394
# [09:08:02] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1491.79285	validation_1-rmse:4405.65140
# [100]	validation_0-rmse:550.39375	validation_1-rmse:2388.29792
# [200]	validation_0-rmse:203.90179	validation_1-rmse:1581.23395
# [300]	validation_0-rmse:76.90444	validation_1-rmse:1235.93713
# [400]	validation_0-rmse:31.92833	validation_1-rmse:1084.60425
# [500]	validation_0-rmse:18.24208	validation_1-rmse:1026.11033
# [600]	validation_0-rmse:15.10560	validation_1-rmse:1004.44760
# [700]	validation_0-rmse:14.26955	validation_1-rmse:988.73769
# [800]	validation_0-rmse:13.92779	validation_1-rmse:980.04962
# [900]	validation_0-rmse:13.73106	validation_1-rmse:976.48224
# [999]	validation_0-rmse:13.57367	validation_1-rmse:974.38229
# [09:08:14] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1508.10958	validation_1-rmse:4408.12597
# [100]	validation_0-rmse:556.59169	validation_1-rmse:2327.21584
# [200]	validation_0-rmse:206.35646	validation_1-rmse:1466.37179
# [300]	validation_0-rmse:77.90093	validation_1-rmse:1081.74354
# [400]	validation_0-rmse:32.30892	validation_1-rmse:920.62790
# [500]	validation_0-rmse:18.37293	validation_1-rmse:850.17506
# [600]	validation_0-rmse:15.14177	validation_1-rmse:824.27258
# [700]	validation_0-rmse:14.32899	validation_1-rmse:809.23676
# [800]	validation_0-rmse:14.01579	validation_1-rmse:801.67728
# [900]	validation_0-rmse:13.82199	validation_1-rmse:798.05542
# [999]	validation_0-rmse:13.69043	validation_1-rmse:795.91764
# [09:08:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1526.59189	validation_1-rmse:4618.09547
# [100]	validation_0-rmse:563.63797	validation_1-rmse:2418.98798
# [200]	validation_0-rmse:209.02388	validation_1-rmse:1505.61133
# [300]	validation_0-rmse:78.90021	validation_1-rmse:1111.34641
# [400]	validation_0-rmse:32.68581	validation_1-rmse:954.54162
# [500]	validation_0-rmse:18.55635	validation_1-rmse:877.12077
# [600]	validation_0-rmse:15.30275	validation_1-rmse:845.59390
# [700]	validation_0-rmse:14.45224	validation_1-rmse:830.82974
# [800]	validation_0-rmse:14.13674	validation_1-rmse:822.09351
# [900]	validation_0-rmse:13.94108	validation_1-rmse:818.37380
# [999]	validation_0-rmse:13.78794	validation_1-rmse:814.96330
# [09:08:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1546.17174	validation_1-rmse:4557.04084
# [100]	validation_0-rmse:570.96598	validation_1-rmse:2258.99015
# [200]	validation_0-rmse:211.76441	validation_1-rmse:1327.95243
# [300]	validation_0-rmse:79.92081	validation_1-rmse:934.77077
# [400]	validation_0-rmse:33.15874	validation_1-rmse:763.24299
# [500]	validation_0-rmse:18.95803	validation_1-rmse:661.22127
# [600]	validation_0-rmse:15.71528	validation_1-rmse:617.04407
# [700]	validation_0-rmse:14.81006	validation_1-rmse:590.08340
# [800]	validation_0-rmse:14.45217	validation_1-rmse:577.18503
# [900]	validation_0-rmse:14.21993	validation_1-rmse:568.99566
# [999]	validation_0-rmse:14.03584	validation_1-rmse:563.72021
# [09:08:53] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1568.19288	validation_1-rmse:4367.21978
# [100]	validation_0-rmse:579.30735	validation_1-rmse:1952.11102
# [200]	validation_0-rmse:214.95776	validation_1-rmse:950.65160
# [300]	validation_0-rmse:81.08521	validation_1-rmse:533.90653
# [400]	validation_0-rmse:33.48729	validation_1-rmse:368.09604
# [500]	validation_0-rmse:19.01468	validation_1-rmse:299.50173
# [600]	validation_0-rmse:15.66167	validation_1-rmse:277.26676
# [700]	validation_0-rmse:14.75377	validation_1-rmse:265.52996
# [800]	validation_0-rmse:14.40774	validation_1-rmse:262.51665
# [900]	validation_0-rmse:14.19465	validation_1-rmse:260.83804
# [999]	validation_0-rmse:14.01810	validation_1-rmse:257.18111
# [09:09:07] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1591.14293	validation_1-rmse:4130.53619
# [100]	validation_0-rmse:587.83310	validation_1-rmse:1614.02926
# [200]	validation_0-rmse:218.09482	validation_1-rmse:644.84039
# [300]	validation_0-rmse:82.29811	validation_1-rmse:282.92228
# [400]	validation_0-rmse:33.95045	validation_1-rmse:144.72607
# [500]	validation_0-rmse:19.17431	validation_1-rmse:101.56320
# [600]	validation_0-rmse:15.74994	validation_1-rmse:92.13794
# [700]	validation_0-rmse:14.82313	validation_1-rmse:88.21847
# [800]	validation_0-rmse:14.45970	validation_1-rmse:85.86149
# [900]	validation_0-rmse:14.24068	validation_1-rmse:84.26321
# [999]	validation_0-rmse:14.08503	validation_1-rmse:83.64533
# [09:09:20] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1615.71844	validation_1-rmse:3847.01127
# [100]	validation_0-rmse:596.97930	validation_1-rmse:1383.18499
# [200]	validation_0-rmse:221.56615	validation_1-rmse:512.16957
# [300]	validation_0-rmse:83.57835	validation_1-rmse:195.18520
# [400]	validation_0-rmse:34.39040	validation_1-rmse:90.61982
# [500]	validation_0-rmse:19.31513	validation_1-rmse:70.52040
# [600]	validation_0-rmse:15.75751	validation_1-rmse:68.59204
# [675]	validation_0-rmse:14.97576	validation_1-rmse:68.59651
# [09:09:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1639.78100	validation_1-rmse:4053.75797
# [100]	validation_0-rmse:605.87370	validation_1-rmse:1445.83044
# [200]	validation_0-rmse:224.85312	validation_1-rmse:524.19795
# [300]	validation_0-rmse:84.84246	validation_1-rmse:194.58601
# [400]	validation_0-rmse:34.90259	validation_1-rmse:77.98335
# [500]	validation_0-rmse:19.54613	validation_1-rmse:65.67860
# [511]	validation_0-rmse:18.84248	validation_1-rmse:66.33515
# [09:09:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1665.82049	validation_1-rmse:3701.24116
# [100]	validation_0-rmse:615.68187	validation_1-rmse:1348.86371
# [200]	validation_0-rmse:228.58819	validation_1-rmse:488.98199
# [300]	validation_0-rmse:86.24102	validation_1-rmse:166.70479
# [400]	validation_0-rmse:35.40783	validation_1-rmse:68.44258
# [500]	validation_0-rmse:19.77139	validation_1-rmse:60.36950
# [519]	validation_0-rmse:18.58037	validation_1-rmse:60.94124
# [09:09:43] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1689.68719	validation_1-rmse:3893.01342
# [100]	validation_0-rmse:624.51578	validation_1-rmse:1399.07257
# [200]	validation_0-rmse:231.83061	validation_1-rmse:509.66000
# [300]	validation_0-rmse:87.45587	validation_1-rmse:185.67694
# [400]	validation_0-rmse:35.94981	validation_1-rmse:81.95954
# [500]	validation_0-rmse:20.13206	validation_1-rmse:65.97406
# [580]	validation_0-rmse:16.75745	validation_1-rmse:65.76515
# [09:09:50] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1711.42580	validation_1-rmse:3983.96898
# [100]	validation_0-rmse:632.45341	validation_1-rmse:1419.39134
# [200]	validation_0-rmse:234.75039	validation_1-rmse:511.55166
# [300]	validation_0-rmse:88.58398	validation_1-rmse:183.03946
# [400]	validation_0-rmse:36.48180	validation_1-rmse:73.66324
# [500]	validation_0-rmse:20.51875	validation_1-rmse:53.75042
# [600]	validation_0-rmse:16.78948	validation_1-rmse:52.06293
# [640]	validation_0-rmse:16.30875	validation_1-rmse:52.08349
# [09:09:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-07593ffd91cd9da33-1\xgboost\xgboost-ci-windows\src\objective\regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:1729.63687	validation_1-rmse:3982.58741
# [100]	validation_0-rmse:639.13426	validation_1-rmse:1426.71328
# [200]	validation_0-rmse:237.23652	validation_1-rmse:522.35356
# [300]	validation_0-rmse:89.58018	validation_1-rmse:189.99683
# [400]	validation_0-rmse:37.03723	validation_1-rmse:74.63072
# [500]	validation_0-rmse:21.01930	validation_1-rmse:48.17136
# [600]	validation_0-rmse:17.28235	validation_1-rmse:45.49083
# [618]	validation_0-rmse:17.04018	validation_1-rmse:45.43647

# %%
print(f'Average score across folds: {np.mean(scores):0.4f}')
print(f'Fold scores:{scores}')
# Out:
# Average score across folds: 289.7991
# Fold scores:[301.3034161897235, 297.78150556061775, 390.163057963001, 281.7444984956114, 252.32805994280477, 296.33012037181396, 309.4045851154075, 94.18136786254182, 45.71531834362878, 19.484942051726406, 65.6047084722639, 60.172055176811305, 81.96837894196496, 70.60831703221987, 170.45083157934383, 332.22850301268284, 316.36515814340777, 77.50219939828962, 116.53709413092515, 301.4694486324399, 287.15404190998333, 259.94441952040734, 481.5077978058535, 615.947341763415, 830.3291874722062, 811.0039432824394, 974.3822834006806, 795.9176348862125, 814.9632963085899, 563.7202106366569, 257.1811065901165, 83.63640770532615, 68.49483181874585, 64.30455849549166, 59.79563835384092, 65.54191557204474, 52.058630080185644, 45.14018184518335]

# %% [markdown]
# # Conclusion:
#
# Lets compare our results between the XGBoost model and Prophet. Before doing that, these are the parameters that we input to each Cross Validation package:
#
# Splits: 10
# Training Length: 730 days
# Testing Length: 37 Days
# Gap: 180 Days
#
# Here are the results for the testing lengths of 37 days:
#
# XGBoost rmse: 289
# Prophet rmse: 16
#
# Shortcomings: We must notice that though we have standardized the inputs to each of the cross validation models, we did use two different Cross Validation models. Nevertheless, it is safe to assume that the Prophet model performed better since not even the best fold from XGBoost reached the average prophet model rmse.

# %% [markdown]
# # Next Steps:
#
# 1. Remove Outliers
# 2. Create Lag predictors
# 3. Create hyper-predictors
# 4. Add more assets
